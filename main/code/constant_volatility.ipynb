# %%
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
df = pd.read_excel('/Users/nannaingemannohrt/Desktop/master_thesis/main/data/ATM_10Y_10Y_from_2004_2024.xlsx', sheet_name='Ark1', engine='openpyxl')

plt.figure(figsize=(10, 6))
plt.plot(df["Dato"],df["ATM_10Y_10Y"], color='grey', label= 'Swaption EUR 10Y10Y')
plt.title('Swaption EUR 10Y10Y', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Yswaption.pdf")
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Yswaption.png")
plt.show()
plt.close()

# %%
returns= df["ATM_10Y_10Y"].pct_change()
plt.figure(figsize=(10, 6))
plt.plot(df["Dato"], returns, label='Daily Returns Swaption EUR 10Y10Y', color='tab:blue')
plt.title('Daily Returns Swaption EUR 10Y10Y')
plt.xlabel('Year')
plt.ylabel('Returns')
plt.legend()
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Yswaptionreturn.pdf")
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Yswaptionreturn.png")
plt.show()
plt.close()

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Download S&P 500 data from Yahoo Finance
sp500 = yf.download('^GSPC', start='2004-01-01', end='2024-01-01')

# Calculate daily returns
sp500['Returns'] = sp500['Adj Close'].pct_change()
plt.figure(figsize=(10, 6))
plt.plot(sp500.index,sp500['Adj Close'], color='grey', label= 'S&P 500 (close values)')
plt.title('S&P 500 (close values)', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/sp500.pdf")
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/sp500.png")
plt.show()
plt.close()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Plot daily returns
plt.figure(figsize=(10, 6))
plt.plot(sp500.index, sp500['Returns'], label='Daily Returns', color='tab:blue')

plt.title('Daily Returns of S&P 500')
plt.xlabel('Date')
plt.ylabel('Returns')
plt.legend()
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/sp500return.pdf")
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/sp500return.png")
plt.show()
plt.close()
