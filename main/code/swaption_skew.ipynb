# Read the data into a pandas DataFrame
df_OTM_2024 = pd.read_csv(OTM_2024_io, sep=" ")
df_OTM_2024 = df_OTM_2024 / 10
df_OTM_2023 = pd.read_csv(OTM_2023_io, sep=" ")
df_OTM_2023 =df_OTM_2023 /10

#Print the data
df_OTM_2024
df_OTM_2023
# Out:
#            -200     -100      -75      -50      -25      ATM       25  \
# 10Y1Y   0.49351  0.50777  0.51273  0.51820  0.52415  0.53057  0.53743
# 10Y2Y   0.49500  0.50855  0.51340  0.51876  0.52459  0.53088  0.53759
# 10Y3Y   0.49068  0.50022  0.50417  0.50864  0.51361  0.51904  0.52500
# 10Y5Y   0.48816  0.48983  0.49200  0.49473  0.49799  0.50165  0.50608
# 10Y7Y   0.48204  0.47899  0.48056  0.48269  0.48532  0.48817  0.49209
# 10Y10Y  0.48155  0.46829  0.46799  0.46842  0.46948  0.47058  0.47344
# 10Y12Y  0.46756  0.45248  0.45151  0.45172  0.45290  0.45295  0.45569
# 10Y15Y  0.45357  0.43667  0.43543  0.43502  0.43531  0.43512  0.43795
# 10Y20Y  0.43837  0.41873  0.41670  0.41559  0.41523  0.41442  0.41672
# 10Y30Y  0.41880  0.39680  0.39409  0.39248  0.39170  0.39121  0.39254
#
#              50       75      100      200
# 10Y1Y   0.54471  0.55238  0.56043  0.59581
# 10Y2Y   0.54472  0.55225  0.56015  0.59503
# 10Y3Y   0.53138  0.53820  0.54544  0.57812
# ...

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_1_y_2023 = df_OTM_2023.loc['10Y1Y']
ten_y_1_y_2024 = df_OTM_2024.loc['10Y1Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y1Y_2023 = ten_y_1_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y1Y_2024 = ten_y_1_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y1Y_2023, ten_y_1_y_2023.values, color='grey', label='EUR10Y1Y - 2023')
plt.plot(OTM_10Y1Y_2024, ten_y_1_y_2024.values, color='red',  label='EUR10Y1Y - 2024')
plt.title('Swaption EUR 10Y1Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y1Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_2_y_2023 = df_OTM_2023.loc['10Y2Y']
ten_y_2_y_2024 = df_OTM_2024.loc['10Y2Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y2Y_2023 = ten_y_2_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y2Y_2024 = ten_y_2_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y2Y_2023, ten_y_2_y_2023.values, color='grey', label='EUR10Y2Y - 2023')
plt.plot(OTM_10Y2Y_2024, ten_y_2_y_2024.values, color='red',  label='EUR10Y2Y - 2024')
plt.title('Swaption EUR 10Y2Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y2Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_3_y_2023 = df_OTM_2023.loc['10Y3Y']
ten_y_3_y_2024 = df_OTM_2024.loc['10Y3Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y3Y_2023 = ten_y_3_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y3Y_2024 = ten_y_3_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y3Y_2023, ten_y_3_y_2023.values, color='grey', label='EUR10Y3Y - 2023')
plt.plot(OTM_10Y3Y_2024, ten_y_3_y_2024.values, color='red',  label='EUR10Y3Y - 2024')
plt.title('Swaption EUR 10Y3Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y3Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_5_y_2023 = df_OTM_2023.loc['10Y5Y']
ten_y_5_y_2024 = df_OTM_2024.loc['10Y5Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y5Y_2023 = ten_y_5_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y5Y_2024 = ten_y_5_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y5Y_2023, ten_y_5_y_2023.values, color='grey', label='EUR10Y5Y - 2023')
plt.plot(OTM_10Y5Y_2024, ten_y_5_y_2024.values, color='red',  label='EUR10Y5Y - 2024')
plt.title('Swaption EUR 10Y5Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y5Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_7_y_2023 = df_OTM_2023.loc['10Y7Y']
ten_y_7_y_2024 = df_OTM_2024.loc['10Y7Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y7Y_2023 = ten_y_7_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y7Y_2024 = ten_y_7_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y7Y_2023, ten_y_7_y_2023.values, color='grey', label='EUR10Y7Y - 2023')
plt.plot(OTM_10Y7Y_2024, ten_y_7_y_2024.values, color='red',  label='EUR10Y7Y - 2024')
plt.title('Swaption EUR 10Y7Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y7Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_ten_y_2023 = df_OTM_2023.loc['10Y10Y']
ten_y_ten_y_2024 = df_OTM_2024.loc['10Y10Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y10Y_2023 = ten_y_ten_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y10Y_2024 = ten_y_ten_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y10Y_2023, ten_y_ten_y_2023.values, color='grey', label='EUR10Y10Y - 2023')
plt.plot(OTM_10Y10Y_2024, ten_y_ten_y_2024.values, color='red',  label='EUR10Y10Y - 2024')
plt.title('Swaption EUR 10Y10Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_12_y_2023 = df_OTM_2023.loc['10Y12Y']
ten_y_12_y_2024 = df_OTM_2024.loc['10Y12Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y12Y_2023 = ten_y_12_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y12Y_2024 = ten_y_12_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y12Y_2023, ten_y_12_y_2023.values, color='grey', label='EUR10Y12Y - 2023')
plt.plot(OTM_10Y12Y_2024, ten_y_12_y_2024.values, color='red',  label='EUR10Y12Y - 2024')
plt.title('Swaption EUR 10Y12Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y12Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_15_y_2023 = df_OTM_2023.loc['10Y15Y']
ten_y_15_y_2024 = df_OTM_2024.loc['10Y15Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y15Y_2023 = ten_y_15_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y15Y_2024 = ten_y_15_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y15Y_2023, ten_y_15_y_2023.values, color='grey', label='EUR10Y15Y - 2023')
plt.plot(OTM_10Y15Y_2024, ten_y_15_y_2024.values, color='red',  label='EUR10Y15Y - 2024')
plt.title('Swaption EUR 10Y15Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y15Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_20_y_2023 = df_OTM_2023.loc['10Y20Y']
ten_y_20_y_2024 = df_OTM_2024.loc['10Y20Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y20Y_2023 = ten_y_20_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y20Y_2024 = ten_y_20_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y20Y_2023, ten_y_20_y_2023.values, color='grey', label='EUR10Y20Y - 2023')
plt.plot(OTM_10Y20Y_2024, ten_y_20_y_2024.values, color='red',  label='EUR10Y20Y - 2024')
plt.title('Swaption EUR 10Y20Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y20Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()

# %%
# Extract the '10Y10Y' row from the original dataframe
ten_y_30_y_2023 = df_OTM_2023.loc['10Y30Y']
ten_y_30_y_2024 = df_OTM_2024.loc['10Y30Y']

# Convert indices to integer deltas (spread measure in bps)
OTM_10Y30Y_2023 = ten_y_30_y_2023.index.str.replace('ATM', '0').astype(int)
OTM_10Y30Y_2024 = ten_y_30_y_2024.index.str.replace('ATM', '0').astype(int)


plt.figure(figsize=(10, 6))
plt.plot(OTM_10Y30Y_2023, ten_y_30_y_2023.values, color='grey', label='EUR10Y30Y - 2023')
plt.plot(OTM_10Y30Y_2024, ten_y_30_y_2024.values, color='red',  label='EUR10Y30Y - 2024')
plt.title('Swaption EUR 10Y30Y Skew', fontsize=18)
plt.xlabel('Strike', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y30Y.png")  # Save as PNG

# Display the plot
plt.show()
plt.close()
