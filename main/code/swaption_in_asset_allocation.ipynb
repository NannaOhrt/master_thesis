# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Tickers for European equities (FEZ), nominal bonds (AGG), inflation-linked bonds (TIP), and 10-Year Treasury Yield (^TNX)
tickers = ['FEZ', 'AGG', 'TIP', '^TNX']

# Start and end dates for the data
start_date = '2004-01-01'
end_date = '2024-01-01'

plt.figure(figsize=(12, 8))

for ticker in tickers:
    # Download historical data for the ticker
    data = yf.download(ticker, start=start_date, end=end_date)
    
    # Calculate daily returns
    data['Returns'] = data['Adj Close'].pct_change()
    
    # Assuming risk-free rate is 0, so excess returns are equal to actual returns in this case
    data['Excess Returns'] = data['Returns']
    
    # Calculate cumulative excess returns
    data['Cumulative Excess Returns'] = (1 + data['Excess Returns']).cumprod()
    
    # Normalize starting point to 100 for comparison
    initial_value = data['Cumulative Excess Returns'].dropna().iloc[0]
    data['Normalized Cumulative Excess Returns'] = data['Cumulative Excess Returns'] / initial_value * 100
    
    # Plot the normalized cumulative excess returns for each ticker
    plt.plot(data.index, data['Normalized Cumulative Excess Returns'], label=f'{ticker}')

# Adjust plot settings for better visualization
plt.title('Comparison of Normalized Cumulative Excess Returns', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Normalized Cumulative Excess Returns', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /Users/nannaingemannohrt/anaconda3/envs/master_thesis_venv/lib/python3.10/site-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
df = pd.read_excel('/Users/nannaingemannohrt/Desktop/master_thesis/main/data/ATM_10Y_10Y_from_2004_2024.xlsx', sheet_name='Ark1', engine='openpyxl')

plt.figure(figsize=(10, 6))
plt.plot(df["Dato"],df["ATM_10Y_10Y"], color='grey', label= 'Swaption EUR 10Y10Y')
plt.title('Swaption EUR 10Y10Y', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Implied Volatility', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/10Y10Yswaption.png")
plt.show()
plt.close()

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Load the swaption data from the Excel file
df = pd.read_excel('/Users/nannaingemannohrt/Desktop/master_thesis/main/data/ATM_10Y_10Y_from_2004_2024.xlsx', 
                   sheet_name='Ark1', engine='openpyxl')

# Normalize the 'ATM_10Y_10Y' column to start at 100
initial_value = df['ATM_10Y_10Y'].dropna().iloc[0]
df['Normalized ATM_10Y_10Y'] = df['ATM_10Y_10Y'] / initial_value * 100



import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Tickers for European equities (FEZ), nominal bonds (AGG), inflation-linked bonds (TIP)
tickers = ['FEZ', 'AGG', 'TIP']

# Start and end dates for the data
start_date = '2004-01-01'
end_date = '2024-01-01'

plt.figure(figsize=(10, 6))

# Define colors for better control and visualization
colors = {'FEZ': 'cadetblue', 'AGG': 'darkred', 'TIP': 'darkorange'}

for ticker in tickers:
    # Download historical data for the ticker
    data = yf.download(ticker, start=start_date, end=end_date)
    
    # Calculate daily returns
    data['Returns'] = data['Adj Close'].pct_change()
    
    # Assuming risk-free rate is 0, so excess returns are equal to actual returns in this case
    data['Excess Returns'] = data['Returns']
    
    # Calculate cumulative excess returns
    data['Cumulative Excess Returns'] = (1 + data['Excess Returns']).cumprod()
    
    # Normalize starting point to 100 for comparison
    initial_value = data['Cumulative Excess Returns'].dropna().iloc[0]
    data['Normalized Cumulative Excess Returns'] = data['Cumulative Excess Returns'] / initial_value * 100
    
    # Plot the normalized cumulative excess returns for each ticker
    plt.plot(data.index, data['Normalized Cumulative Excess Returns'], label=f'{ticker}', 
             color=colors[ticker])

# Adjust plot settings for better visualization
plt.title('Comparison of Normalized Cumulative Excess Returns', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Normalized Cumulative Excess Returns', fontsize=14)
plt.plot(df["Dato"], df["Normalized ATM_10Y_10Y"], color='grey', label='Swaption EUR 10Y10Y ')
plt.legend(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/2004_to_2024_plot.png") 
plt.show()
plt.close()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Load the swaption data from the Excel file
df1 = pd.read_excel('/Users/nannaingemannohrt/Desktop/master_thesis/main/data/ATTM_2022_to_2024.xlsx', 
                    sheet_name='Ark1', engine='openpyxl')

# Normalize the 'ATM_10Y_10Y' column to start at 100
initial_value = df1['ATM_10Y_10Y'].dropna().iloc[0]
df1['Normalized ATM_10Y_10Y'] = df1['ATM_10Y_10Y'] / initial_value * 100


# Tickers for European equities (FEZ), nominal bonds (AGG), inflation-linked bonds (TIP)
tickers = ['FEZ', 'AGG', 'TIP']

# Start and end dates for the data
start_date = '2022-01-04'
end_date = '2024-01-01'

plt.figure(figsize=(10, 6))

# Define colors for better control and visualization
colors = {'FEZ': 'cadetblue', 'AGG': 'darkred', 'TIP': 'darkorange'}

for ticker in tickers:
    # Download historical data for the ticker
    data = yf.download(ticker, start=start_date, end=end_date)
    
    # Calculate daily returns
    data['Returns'] = data['Adj Close'].pct_change()
    
    # Assuming risk-free rate is 0, so excess returns are equal to actual returns in this case
    data['Excess Returns'] = data['Returns']
    
    # Calculate cumulative excess returns
    data['Cumulative Excess Returns'] = (1 + data['Excess Returns']).cumprod()
    
    # Normalize starting point to 100 for comparison
    initial_value = data['Cumulative Excess Returns'].dropna().iloc[0]
    data['Normalized Cumulative Excess Returns'] = data['Cumulative Excess Returns'] / initial_value * 100
    
    # Plot the normalized cumulative excess returns for each ticker
    plt.plot(data.index, data['Normalized Cumulative Excess Returns'], label=f'{ticker}', 
             color=colors[ticker])

# Adjust plot settings for better visualization
plt.title('Comparison of Normalized Cumulative Excess Returns', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Normalized Cumulative Excess Returns', fontsize=14)
plt.plot(df1["Dato"], df1["Normalized ATM_10Y_10Y"], color='grey', label='Swaption EUR 10Y10Y ')
plt.legend(fontsize=12, loc= 'upper left')
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/2022_to_2024.png") 
plt.show()
plt.close()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Load the swaption data from the Excel file
df2 = pd.read_excel('/Users/nannaingemannohrt/Desktop/master_thesis/main/data/ATM_2007_to_2012.xlsx', 
                    sheet_name='Ark1', engine='openpyxl')

# Normalize the 'ATM_10Y_10Y' column to start at 100
initial_value = df2['ATM_10Y_10Y'].dropna().iloc[0]
df2['Normalized ATM_10Y_10Y'] = df2['ATM_10Y_10Y'] / initial_value * 100


# Tickers for European equities (FEZ), nominal bonds (AGG), inflation-linked bonds (TIP)
tickers = ['FEZ', 'AGG', 'TIP']

# Start and end dates for the data
start_date = '2007-01-02'
end_date = '2010-12-31'

plt.figure(figsize=(10, 6))

# Define colors for better control and visualization
colors = {'FEZ': 'cadetblue', 'AGG': 'darkred', 'TIP': 'darkorange'}

for ticker in tickers:
    # Download historical data for the ticker
    data = yf.download(ticker, start=start_date, end=end_date)
    
    # Calculate daily returns
    data['Returns'] = data['Adj Close'].pct_change()
    
    # Assuming risk-free rate is 0, so excess returns are equal to actual returns in this case
    data['Excess Returns'] = data['Returns']
    
    # Calculate cumulative excess returns
    data['Cumulative Excess Returns'] = (1 + data['Excess Returns']).cumprod()
    
    # Normalize starting point to 100 for comparison
    initial_value = data['Cumulative Excess Returns'].dropna().iloc[0]
    data['Normalized Cumulative Excess Returns'] = data['Cumulative Excess Returns'] / initial_value * 100
    
    # Plot the normalized cumulative excess returns for each ticker
    plt.plot(data.index, data['Normalized Cumulative Excess Returns'], label=f'{ticker}', 
             color=colors[ticker])

# Adjust plot settings for better visualization
plt.title('Comparison of Normalized Cumulative Excess Returns', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Normalized Cumulative Excess Returns', fontsize=14)
plt.plot(df2["Dato"], df2["Normalized ATM_10Y_10Y"], color='grey', label='Swaption EUR 10Y10Y ')
plt.legend(fontsize=12)
plt.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig("/Users/nannaingemannohrt/Desktop/master_thesis/main/plots/2007_to_2011.png") 
plt.show()
plt.close()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
